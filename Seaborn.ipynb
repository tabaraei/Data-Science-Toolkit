# %% [markdown]
# <a href="https://colab.research.google.com/github/tabaraei/CheatSheet/blob/master/notebooks/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

sns.set_style('darkgrid')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/tabaraei/CheatSheet/master/datasets/mpg.csv')
sns.distplot(df[df['cyl'] == 4].hwy)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize=(7, 7))
ax = sns.scatterplot(data=df, x='displ', y='hwy', hue='cyl', size='cyl', palette='Set2') # palette GnBu_d, Set1, Set3, magma, spring, cubehelix
plt.show()

# %% [markdown]
# # Bar Chart:

# %%
plt.figure(figsize=(8, 4))
ax = sns.barplot(data=df, x='class', y='cty', palette='Set3', ci=None, estimator=np.mean)
plt.show()

# %% [markdown]
# # Box Plot:

# %%
plt.figure(figsize=(12, 8))
ax = sns.boxplot(data=df, x='class', y='hwy', palette='Set3', showfliers=True)
plt.show()

# %% [markdown]
# # Heat Map:

# %%
plt.figure(figsize=(8, 6))
ax = sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
map = pd.crosstab(index=df['manufacturer'], columns=df['year'])
ax = sns.heatmap(map, annot=True)
plt.show()

# %% [markdown]
# # Not Organized

# %%
http://seaborn.pydata.org/api.html
